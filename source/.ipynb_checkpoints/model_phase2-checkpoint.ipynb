# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os
import matplotlib.pylab as plt
from sklearn.metrics import roc_curve, roc_auc_score, recall_score
from tensorflow.keras.applications import InceptionResNetV2, ResNet50, InceptionV3, DenseNet121, Xception
import tensorflow_hub as hub
# Out:
# 2023-04-20 16:16:35.977489: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-20 16:16:37.000518: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#set tensorflow to use CPU
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
img_size = 512
batch_size = 16
num_classes = 9
train_dir = '../data/frames/train'
test_dir = '../data/frames/test'
def get_ds():
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(train_dir, label_mode='categorical', shuffle=False, image_size=(img_size, img_size), batch_size=batch_size, validation_split=0.2, subset='training')
    val_ds = tf.keras.preprocessing.image_dataset_from_directory(train_dir, label_mode='categorical', shuffle=False, image_size=(img_size, img_size), batch_size=batch_size, validation_split=0.2, subset='validation')
    test_ds = tf.keras.preprocessing.image_dataset_from_directory(test_dir, label_mode='categorical', shuffle=False, image_size=(img_size, img_size), batch_size=batch_size)
    #Apply data augmentation
    preprocessing_model = tf.keras.Sequential()
    preprocessing_model.add(
        tf.keras.layers.experimental.preprocessing.RandomRotation(40))
    preprocessing_model.add(
        tf.keras.layers.experimental.preprocessing.RandomTranslation(0.2, 0.2))
    preprocessing_model.add(
        tf.keras.layers.experimental.preprocessing.RandomZoom(0.2, 0.2))
    preprocessing_model.add(
        tf.keras.layers.experimental.preprocessing.RandomFlip(mode="horizontal"))
    preprocessing_model.add(
        tf.keras.layers.experimental.preprocessing.RandomFlip(mode="vertical"))

    train_ds = train_ds.map(lambda images, labels:
                            (preprocessing_model(images), labels))
    
    val_ds = val_ds.map(lambda images, labels:
                            (preprocessing_model(images), labels))
    
    #prefetch datasets
    train_ds = train_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    val_ds = val_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    test_ds = test_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return train_ds, val_ds, test_ds

# %%
n_layers = 2
n_neurons = 512
n_dropout = 0.2
def get_model():
    base_model = tf.keras.applications.InceptionResNetV2(include_top=False, weights='imagenet', input_shape=(img_size, img_size, 3))
    preprocess_fx = tf.keras.applications.inception_resnet_v2.preprocess_input
    
    inputs = tf.keras.Input(shape=(img_size, img_size, 3))
    y = preprocess_fx(inputs)
    y = base_model(y, training=True)
    y = tf.keras.layers.GlobalAveragePooling2D()(y)
    y = tf.keras.layers.Dropout(n_dropout)(y)
    y = tf.keras.layers.Dense(n_neurons, activation='relu')(y)
    y = tf.keras.layers.Dropout(n_dropout)(y)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(y)
    model = tf.keras.Model(inputs, outputs)
    
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=3e-4),
                loss=keras.losses.CategoricalCrossentropy(),
                metrics=['categorical_accuracy'])
    #set the base model to be trainable
    base_model.trainable = True
    return model

# %%
early_stopping = keras.callbacks.EarlyStopping(patience=15, min_delta=1e-6, restore_best_weights=True)

# %%
# strategy = tf.distribute.MirroredStrategy()
# print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# with strategy.scope():
model = get_model()
train_ds, val_ds, test_ds = get_ds()
# Out:
# 2023-04-20 16:16:41.478628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18237 MB memory:  -> device: 0, name: NVIDIA RTX A4500, pci bus id: 0000:81:00.0, compute capability: 8.6
# 2023-04-20 16:16:41.479334: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 10358 MB memory:  -> device: 1, name: NVIDIA TITAN V, pci bus id: 0000:02:00.0, compute capability: 7.0
# Found 5493 files belonging to 9 classes.
# Using 4395 files for training.
# Found 5493 files belonging to 9 classes.
# Using 1098 files for validation.
# Found 1610 files belonging to 8 classes.

# %%
epochs = 500
history = model.fit(train_ds, epochs=epochs, validation_data=val_ds, callbacks=[early_stopping])
# Out:
# 2023-04-20 16:16:53.439287: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_16' with dtype resource
# 	 [[{{node Placeholder/_16}}]]
# 2023-04-20 16:16:53.439893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_16' with dtype resource
# 	 [[{{node Placeholder/_16}}]]
# Epoch 1/500
# 2023-04-20 16:17:43.276059: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8900
# 2023-04-20 16:17:51.228287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-04-20 16:17:51.254452: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x640399f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-04-20 16:17:51.254488: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A4500, Compute Capability 8.6
# 2023-04-20 16:17:51.254507: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (1): NVIDIA TITAN V, Compute Capability 7.0
# 2023-04-20 16:17:51.298771: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-04-20 16:17:51.713592: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 275/275 [==============================] - ETA: 0s - loss: 1.6539 - categorical_accuracy: 0.5668
# 2023-04-20 16:27:22.888235: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_18' with dtype resource
# 	 [[{{node Placeholder/_18}}]]
# 2023-04-20 16:27:22.888792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_17' with dtype resource
# 	 [[{{node Placeholder/_17}}]]
# 275/275 [==============================] - 756s 2s/step - loss: 1.6539 - categorical_accuracy: 0.5668 - val_loss: 2.2129 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/500
# 275/275 [==============================] - 611s 2s/step - loss: 1.5868 - categorical_accuracy: 0.4530 - val_loss: 1.9529 - val_categorical_accuracy: 0.0000e+00
# Epoch 3/500
# 275/275 [==============================] - 612s 2s/step - loss: 1.4619 - categorical_accuracy: 0.5367 - val_loss: 0.8443 - val_categorical_accuracy: 1.0000
# Epoch 4/500
# 275/275 [==============================] - 612s 2s/step - loss: 1.0722 - categorical_accuracy: 0.6262 - val_loss: 0.5461 - val_categorical_accuracy: 1.0000
# Epoch 5/500
# 275/275 [==============================] - 611s 2s/step - loss: 0.9730 - categorical_accuracy: 0.6612 - val_loss: 0.5503 - val_categorical_accuracy: 1.0000
# Epoch 6/500
# 275/275 [==============================] - 609s 2s/step - loss: 0.8047 - categorical_accuracy: 0.7208 - val_loss: 0.6969 - val_categorical_accuracy: 1.0000
# Epoch 7/500
# 275/275 [==============================] - 615s 2s/step - loss: 1.0135 - categorical_accuracy: 0.6173 - val_loss: 0.3965 - val_categorical_accuracy: 0.9827
# Epoch 8/500
# 275/275 [==============================] - 613s 2s/step - loss: 0.9618 - categorical_accuracy: 0.7142 - val_loss: 1.1965 - val_categorical_accuracy: 0.4117
# Epoch 9/500
# 275/275 [==============================] - 615s 2s/step - loss: 1.0578 - categorical_accuracy: 0.5727 - val_loss: 0.9940 - val_categorical_accuracy: 0.8434
# Epoch 10/500
# 275/275 [==============================] - 613s 2s/step - loss: 1.1673 - categorical_accuracy: 0.5060 - val_loss: 1.0717 - val_categorical_accuracy: 0.9107
# Epoch 11/500
# 275/275 [==============================] - 613s 2s/step - loss: 0.9358 - categorical_accuracy: 0.6437 - val_loss: 0.7147 - val_categorical_accuracy: 1.0000
# Epoch 12/500
# 275/275 [==============================] - 614s 2s/step - loss: 0.7554 - categorical_accuracy: 0.7053 - val_loss: 0.9089 - val_categorical_accuracy: 0.8807
# Epoch 13/500
# 275/275 [==============================] - 614s 2s/step - loss: 0.9288 - categorical_accuracy: 0.6319 - val_loss: 1.1766 - val_categorical_accuracy: 0.0000e+00
# Epoch 14/500
# 275/275 [==============================] - 614s 2s/step - loss: 1.0343 - categorical_accuracy: 0.5788 - val_loss: 1.5281 - val_categorical_accuracy: 0.0000e+00
# Epoch 15/500
# 275/275 [==============================] - 664s 2s/step - loss: 1.1701 - categorical_accuracy: 0.5495 - val_loss: 1.2494 - val_categorical_accuracy: 0.0018
# Epoch 16/500
# 275/275 [==============================] - 666s 2s/step - loss: 1.4067 - categorical_accuracy: 0.3820 - val_loss: 0.4341 - val_categorical_accuracy: 0.9927
# Epoch 17/500
# 275/275 [==============================] - 630s 2s/step - loss: 1.1709 - categorical_accuracy: 0.5725 - val_loss: 0.2650 - val_categorical_accuracy: 1.0000
# Epoch 18/500
# 275/275 [==============================] - 608s 2s/step - loss: 0.8635 - categorical_accuracy: 0.6903 - val_loss: 0.2531 - val_categorical_accuracy: 1.0000
# Epoch 19/500
# 275/275 [==============================] - 613s 2s/step - loss: 1.1012 - categorical_accuracy: 0.5970 - val_loss: 1.4808 - val_categorical_accuracy: 0.1330
# Epoch 20/500
# 275/275 [==============================] - 611s 2s/step - loss: 1.2155 - categorical_accuracy: 0.5704 - val_loss: 1.4829 - val_categorical_accuracy: 0.4690
# Epoch 21/500
# 275/275 [==============================] - 613s 2s/step - loss: 1.2464 - categorical_accuracy: 0.5110 - val_loss: 1.2392 - val_categorical_accuracy: 0.3042
# Epoch 22/500
# 275/275 [==============================] - 615s 2s/step - loss: 1.1187 - categorical_accuracy: 0.5677 - val_loss: 1.0443 - val_categorical_accuracy: 0.8515
# Epoch 23/500
# 275/275 [==============================] - 606s 2s/step - loss: 0.9929 - categorical_accuracy: 0.6166 - val_loss: 0.2884 - val_categorical_accuracy: 1.0000
# Epoch 24/500
# 275/275 [==============================] - 644s 2s/step - loss: 1.1904 - categorical_accuracy: 0.5984 - val_loss: 1.3554 - val_categorical_accuracy: 0.2823
# Epoch 25/500
# 275/275 [==============================] - 657s 2s/step - loss: 0.9905 - categorical_accuracy: 0.6553 - val_loss: 0.7895 - val_categorical_accuracy: 0.8597
# Epoch 26/500
# 275/275 [==============================] - 660s 2s/step - loss: 0.8088 - categorical_accuracy: 0.7395 - val_loss: 0.2562 - val_categorical_accuracy: 1.0000
# Epoch 27/500
# 275/275 [==============================] - 659s 2s/step - loss: 0.7094 - categorical_accuracy: 0.7684 - val_loss: 0.2001 - val_categorical_accuracy: 1.0000
# Epoch 28/500
# 275/275 [==============================] - 652s 2s/step - loss: 0.6788 - categorical_accuracy: 0.7914 - val_loss: 0.1673 - val_categorical_accuracy: 1.0000
# Epoch 29/500
# 275/275 [==============================] - 617s 2s/step - loss: 0.7309 - categorical_accuracy: 0.7524 - val_loss: 0.1150 - val_categorical_accuracy: 1.0000
# Epoch 30/500
# 275/275 [==============================] - 617s 2s/step - loss: 0.8837 - categorical_accuracy: 0.6922 - val_loss: 0.3223 - val_categorical_accuracy: 0.9563
# Epoch 31/500
# 275/275 [==============================] - 613s 2s/step - loss: 0.8194 - categorical_accuracy: 0.7126 - val_loss: 0.6907 - val_categorical_accuracy: 0.9317
# Epoch 32/500
# 275/275 [==============================] - 611s 2s/step - loss: 0.9653 - categorical_accuracy: 0.6605 - val_loss: 1.6183 - val_categorical_accuracy: 0.5719
# Epoch 33/500
# 275/275 [==============================] - 611s 2s/step - loss: 1.1444 - categorical_accuracy: 0.6111 - val_loss: 1.2653 - val_categorical_accuracy: 0.4299
# Epoch 34/500
# 275/275 [==============================] - 613s 2s/step - loss: 0.8761 - categorical_accuracy: 0.7015 - val_loss: 0.6041 - val_categorical_accuracy: 0.9891
# Epoch 35/500
# 275/275 [==============================] - 614s 2s/step - loss: 1.0235 - categorical_accuracy: 0.5964 - val_loss: 1.4313 - val_categorical_accuracy: 0.0046
# Epoch 36/500
# 275/275 [==============================] - 611s 2s/step - loss: 0.8739 - categorical_accuracy: 0.7051 - val_loss: 0.9533 - val_categorical_accuracy: 0.9435
# Epoch 37/500
# 275/275 [==============================] - 611s 2s/step - loss: 0.8301 - categorical_accuracy: 0.6767 - val_loss: 0.4487 - val_categorical_accuracy: 1.0000
# Epoch 38/500
# 275/275 [==============================] - 613s 2s/step - loss: 0.8189 - categorical_accuracy: 0.6915 - val_loss: 0.2444 - val_categorical_accuracy: 0.9800
# Epoch 39/500
# 275/275 [==============================] - 615s 2s/step - loss: 0.8182 - categorical_accuracy: 0.7352 - val_loss: 0.4818 - val_categorical_accuracy: 0.9299
# Epoch 40/500
# 275/275 [==============================] - 612s 2s/step - loss: 0.7919 - categorical_accuracy: 0.7716 - val_loss: 0.3109 - val_categorical_accuracy: 1.0000
# Epoch 41/500
# 275/275 [==============================] - 615s 2s/step - loss: 0.7949 - categorical_accuracy: 0.7547 - val_loss: 0.8876 - val_categorical_accuracy: 1.0000
# Epoch 42/500
# 275/275 [==============================] - 614s 2s/step - loss: 0.8681 - categorical_accuracy: 0.7083 - val_loss: 0.3838 - val_categorical_accuracy: 1.0000
# Epoch 43/500
# 275/275 [==============================] - 612s 2s/step - loss: 1.2465 - categorical_accuracy: 0.5149 - val_loss: 0.3832 - val_categorical_accuracy: 1.0000
# Epoch 44/500
# 275/275 [==============================] - 614s 2s/step - loss: 0.8429 - categorical_accuracy: 0.7085 - val_loss: 0.4260 - val_categorical_accuracy: 1.0000

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score, accuracy_score
y_preds = {}
y_trues = {}
for i in range(num_classes):
    y_preds[i] = np.array([])
    y_trues[i] = np.array([])
for images, labels in test_ds:
    pred = model.predict(images)
    for i in range(8):
        y_preds[i] = np.concatenate((y_preds[i], pred[:, i]))
        y_trues[i] = np.concatenate((y_trues[i], labels[:, i]))
# Out:
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 132ms/step

# %%
class_strs = [folder for folder in os.listdir(test_dir) if os.path.isdir]
class_strs.sort()

# %%
class_strs
# Out:
# ['eso_mob',
#  'exposure',
#  'fundus_mob',
#  'hiatal_dissec',
#  'hiatal_repair',
#  'oob',
#  'sac_excision',
#  'wrap']

# %%
results_df = pd.DataFrame(columns=['class', 'auc', 'accuracy'])
for i in range(8):
    auc = roc_auc_score(y_trues[i], y_preds[i])
    acc = accuracy_score(y_trues[i], y_preds[i] > 0.5)
    results_df.loc[i] = [class_strs[i], auc, acc]
results_df
# Out:
#            class       auc  accuracy
# 0        eso_mob  0.480766  0.743478
# 1       exposure  0.647889  0.977640
# 2     fundus_mob  0.461778  0.945963
# 3  hiatal_dissec  0.462442  0.727329
# 4  hiatal_repair  0.498870  0.899379
# 5            oob  0.513999  0.979503
# 6   sac_excision  0.692323  0.990062
# 7           wrap  0.506081  0.736646

# %%
#plot the ROC curves for each class using the y_preds and y_trues dictionaries
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
plt.figure(figsize=(10, 10))
for i in range(8):
    fpr, tpr, _ = roc_curve(y_trues[i], y_preds[i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label='{} (AUC = {:.2f})'.format(class_strs[i], roc_auc))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curves')
plt.legend(loc='best')
plt.savefig('../results/roc_curves.png')

# %%
file_paths = test_ds.file_paths

# %%
#get predictions for each image and save to csv
class_strs.append('image_fname', 'label')
preds_df = pd.DataFrame(columns=class_strs)

# %%
for image in test_ds:
    pred = model.predict(image)
    pred = pred[0]
    pred = np.append(pred, os.path.basename(file_paths[0]))
    pred = np.append(pred, os.path.basename(os.path.dirname(file_paths[0])))
    preds_df.loc[len(preds_df)] = pred
    file_paths = file_paths[1:]
# Out:
# 2023-01-18 16:56:59.331721: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_116997"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\022FlatMapDataset:960"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:56:59.780848: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_117182"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\022FlatMapDataset:986"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:56:59.991201: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_117367"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1012"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:00.165488: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_117552"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1038"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:00.343250: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_117737"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1064"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:00.531129: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_117922"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1090"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:00.737391: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_118107"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1116"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:01.035849: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_118292"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1142"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:01.215845: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_118477"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1168"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:01.410455: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_118662"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1194"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:01.622840: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_118847"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1220"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:01.812837: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_119032"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1246"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:02.014371: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_119217"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1272"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:02.192624: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_119402"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1298"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:02.387743: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_119587"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1324"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:02.576943: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_119772"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1350"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:02.804049: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_119957"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1376"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:03.030571: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_120142"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1402"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:03.341536: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_120327"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1428"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:03.555466: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_120512"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1454"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:03.746639: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_120697"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1480"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:03.959961: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_120882"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1506"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:04.154929: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_121067"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1532"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:04.327743: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_121252"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1558"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:04.499328: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_121437"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1584"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:04.674029: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_121622"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1610"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:04.853995: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_121807"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1636"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:05.054416: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_121992"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1662"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:05.218851: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_122177"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1688"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:05.518924: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_122362"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1714"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:05.684398: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_122547"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1740"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:05.877521: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_122732"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1766"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:06.090748: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_122917"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1792"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:06.276252: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_123102"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1818"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:06.484547: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_123287"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1844"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:06.674495: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_123472"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1870"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:06.880587: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_123657"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1896"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:07.175902: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_123842"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1922"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 16:57:07.392553: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_124027"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\023FlatMapDataset:1948"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# ...
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_366192"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:35982"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:28.491704: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_366377"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36008"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:28.689077: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_366562"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36034"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:28.881986: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_366747"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36060"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:29.104778: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_366932"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36086"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:29.314494: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_367117"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36112"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:29.515960: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_367302"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36138"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:29.741041: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_367487"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36164"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:29.923468: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_367672"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36190"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:30.098902: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_367857"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36216"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:30.268303: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_368042"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36242"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:30.539148: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_368227"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36268"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2023-01-18 17:01:30.747135: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:766] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_368412"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024FlatMapDataset:36294"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.

# %%
preds_df.head()
# Out:
#              oob         other phase_1_exposure phase_2_hiatal_dissec  \
# 0   0.0145383645    0.88687944      0.018921277           0.023483107
# 1  1.9744988e-05  0.0033628787     2.005741e-06         3.8803457e-05
# 2   0.0025292393      0.724156     0.0009202642           0.004356111
# 3    0.055614695     0.7358492       0.07810252           0.053913485
# 4    0.016452251     0.7833865      0.014081486           0.029732594
#
#   phase_3_fundus    phase_4_eso phase_5_hiatal_repair  phase_6_wrap  \
# 0    0.011018063    0.020968148           0.010109716   0.014081824
# 1  6.1614423e-06  6.8650356e-06          0.0034440015     0.9931195
# 2   0.0015864857   0.0086976485            0.09305355    0.16470067
# 3    0.011321764     0.05913351          0.0037437472  0.0023211276
# 4     0.01963642    0.024813775            0.02353263    0.08836426
#
#       image_fname
# 0  vid_1_3565.jpg
# 1  vid_1_4860.jpg
# 2   vid_1_865.jpg
# 3  vid_1_2300.jpg
# 4  vid_1_2465.jpg

# %%
preds_df.to_csv('../data/test/preds.csv')
