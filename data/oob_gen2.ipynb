# %%
import os
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
#time is in the form XXH:XXm:XXs, so we need to convert it to seconds
def convert_time(time):
    hours = int(time[0:2])
    mins = int(time[4:6])
    secs = int(time[8:10])
    return hours*3600 + mins*60 + secs

# %%
phases = pd.read_excel('phases.xlsx')
print(phases.shape)
# Out:
# (579, 6)
# /home/kchen/.local/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
phases.head()
# Out:
#   vid_id          phase   time_start     time_end labeler labeler_2
# 0  vid_0            oob  00H:00m:00s  00H:03m:18s      kc       NaN
# 1  vid_0       exposure  00H:03m:18s  00H:08m:44s      kc       NaN
# 2  vid_0  hiatal_dissec  00H:08m:45s  00H:16m:41s      kc       NaN
# 3  vid_0        eso_mob  00H:16m:42s  00H:18m:21s      kc       NaN
# 4  vid_0  hiatal_dissec  00H:18m:22s  00H:19m:04s      kc       NaN

# %%
phases['vid_id'].value_counts()
# Out:
# vid_id
# vid_7      40
# vid_12     37
# vid_11     37
# vid_23     36
# vid_14     29
# vid_6      28
# vid_21     28
# vid_15     27
# vid_1      25
# yale_7     23
# yale_9     23
# vid_18     22
# vid_13     22
# vid_0      21
# vid_17     20
# vid_22     20
# yale_0     19
# vid_16     19
# vid_5      18
# vid_24     17
# yale_3     12
# yale_4     12
# yale_8     12
# vid_4      11
# yale_5     10
# yale_18     7
# vid_3       3
# vid_25      1
# Name: count, dtype: int64

# %%
#get the number of unique videos
len(phases['vid_id'].unique())
# Out:
# 28

# %%
phases['labeler'].value_counts()
# Out:
# labeler
# kc    251
# sp    177
# ck    109
# AB     42
# Name: count, dtype: int64

# %%
#for each row in the dataframe, make sure that time_start and time_end are integers
for i in range(len(phases)):
    try:
        start1 = convert_time(phases['time_start'][i])
        end1 = convert_time(phases['time_end'][i])
    except:
        print(i)
        print(phases['time_start'][i])
        print(phases['time_end'][i])

# %%
phase_list = phases['phase'].unique()
phase_list
# Out:
# array(['oob', 'exposure', 'hiatal_dissec', 'eso_mob', 'fundus_mob',
#        'sac_excision', 'hiatal_repair', 'peg_placement', 'wrap', 'other',
#        'sac_reduction'], dtype=object)

# %%
#check the total amount of time in the dataset
total_time = 0
for i in range(len(phases)):
    start1 = convert_time(phases['time_start'][i])
    end1 = convert_time(phases['time_end'][i])
    total_time += (end1 - start1)
print(total_time)
# Out:
# 136102

# %%
#get the total time in hours, minutes, and seconds
hours = total_time // 3600
mins = (total_time % 3600) // 60
secs = (total_time % 3600) % 60
print(hours, mins, secs)
# Out:
# 37 48 22

# %%
# for phase1 in phase_list:
#     #if the folder doesn't exist, create it
#     if not os.path.exists('frames/' + phase1):
#         os.makedirs('frames/' + phase1)
#     else:
#         pass

# %%
print(len(phases))
# Out:
# 579

# %%
phases.head()
# Out:
#   vid_id          phase   time_start     time_end labeler labeler_2
# 0  vid_0            oob  00H:00m:00s  00H:03m:18s      kc       NaN
# 1  vid_0       exposure  00H:03m:18s  00H:08m:44s      kc       NaN
# 2  vid_0  hiatal_dissec  00H:08m:45s  00H:16m:41s      kc       NaN
# 3  vid_0        eso_mob  00H:16m:42s  00H:18m:21s      kc       NaN
# 4  vid_0  hiatal_dissec  00H:18m:22s  00H:19m:04s      kc       NaN

# %%
phases['path'] = np.NaN
#if vid_id contains 'vid', then path starts with 'unc/raw_ids', elif vid_id contains 'yale', then path starts with 'yale/raw_ids'
for i, row in phases.iterrows():
    if 'vid' in row['vid_id']:
        phases.loc[i, 'path'] = 'unc/raw_ids/' + row['vid_id'] + '.mp4'
    elif 'yale' in row['vid_id']:
        phases.loc[i, 'path'] = 'yale/raw_ids/' + row['vid_id'] + '.mp4'
    else:
        print('error')

# %%
phases.head()
# Out:
#   vid_id          phase   time_start     time_end labeler labeler_2
# 0  vid_0            oob  00H:00m:00s  00H:03m:18s      kc       NaN  \
# 1  vid_0       exposure  00H:03m:18s  00H:08m:44s      kc       NaN
# 2  vid_0  hiatal_dissec  00H:08m:45s  00H:16m:41s      kc       NaN
# 3  vid_0        eso_mob  00H:16m:42s  00H:18m:21s      kc       NaN
# 4  vid_0  hiatal_dissec  00H:18m:22s  00H:19m:04s      kc       NaN
#
#                     path
# 0  unc/raw_ids/vid_0.mp4
# 1  unc/raw_ids/vid_0.mp4
# 2  unc/raw_ids/vid_0.mp4
# 3  unc/raw_ids/vid_0.mp4
# 4  unc/raw_ids/vid_0.mp4

# %%
phases.tail()
# Out:
#      vid_id          phase   time_start     time_end labeler
# 574  yale_9  hiatal_repair  00H:50m:12s  00H:51m:42s      sp  \
# 575  yale_9          other  00H:51m:43s  00H:52m:43s      sp
# 576  yale_9           wrap  00H:52m:44s  01H:04m:06s      sp
# 577  yale_9          other  01H:04m:07s  01H:04m:15s      sp
# 578  yale_9            oob  01H:04m:16s  01H:04m:59s      sp
#
#                        labeler_2                     path
# 574                          NaN  yale/raw_ids/yale_9.mp4
# 575  readjusting liver retractor  yale/raw_ids/yale_9.mp4
# 576                          NaN  yale/raw_ids/yale_9.mp4
# 577                          NaN  yale/raw_ids/yale_9.mp4
# 578                          NaN  yale/raw_ids/yale_9.mp4

# %%
#sort vid_id in reverse alphabetical order, in order to include yale videos in training set
phases = phases.sort_values(by=['vid_id'], ascending=False)
phases.head()
# Out:
#      vid_id          phase   time_start     time_end labeler
# 578  yale_9            oob  01H:04m:16s  01H:04m:59s      sp  \
# 567  yale_9            oob  00H:41m:22s  00H:41m:32s      sp
# 557  yale_9  sac_reduction  00H:02m:07s  00H:06m:26s      sp
# 558  yale_9  hiatal_dissec  00H:06m:27s  00H:07m:56s      sp
# 559  yale_9          other  00H:07m:57s  00H:08m:50s      sp
#
#                        labeler_2                     path
# 578                          NaN  yale/raw_ids/yale_9.mp4
# 567                          NaN  yale/raw_ids/yale_9.mp4
# 557                          NaN  yale/raw_ids/yale_9.mp4
# 558                          NaN  yale/raw_ids/yale_9.mp4
# 559  readjusting liver retractor  yale/raw_ids/yale_9.mp4

# %%
#find values in 'path' that are not strings
phases[phases['path'].apply(lambda x: type(x) != str)]
# Out:
# Empty DataFrame
# Columns: [vid_id, phase, time_start, time_end, labeler, labeler_2, path]
# Index: []

# %%
vid_id = phases['vid_id'][0]
phase = phases['phase'][0]
time_start = phases['time_start'][0]
time_end = phases['time_end'][0]
vid_fname = phases['path'][0]
time_start_sec = convert_time(time_start)
time_end_sec = convert_time(time_end)
print(time_start_sec, time_end_sec)
# Out:
# 0 198

# %%
vid_fname = phases['path'][0]
vid_fname
# Out:
# 'unc/raw_ids/vid_0.mp4'

# %%
#show the first frame of the video
cap = cv2.VideoCapture(vid_fname)
ret, frame = cap.read()
plt.imshow(frame)
plt.show()

# %%
for i in range(len(phases)):
    if i < 500:
        vid_id = phases['vid_id'][i]
        vid_fname = phases['path'][i]
        phase = phases['phase'][i]
        if phase == 'oob':
            phase = 1
        elif phase != 'oob':
            phase = 0
        time_start = phases['time_start'][i]
        time_end = phases['time_end'][i]
        time_start_sec = convert_time(time_start)
        time_end_sec = convert_time(time_end)
        print(vid_fname)
        if phase == 1:
            for i in range(time_start_sec, time_end_sec):
                if i%5 == 0:
                    cap = cv2.VideoCapture(vid_fname)
                    cap.set(cv2.CAP_PROP_POS_MSEC, i*1000)
                    ret, frame = cap.read()
                    if ret:
                        if not os.path.exists('oob/train/{}'.format(phase)):
                            os.makedirs('oob/train/{}'.format(phase))
                        cv2.imwrite('oob/train/{}/{}_{}.jpg'.format(phase, vid_id, i), frame)
                else:
                    continue
                cap.release()
        elif phase == 0:
            time_start_sec += 5
            time_end_sec -= 5
            for i in range(time_start_sec, time_end_sec):
                if i%20 == 0:
                    cap = cv2.VideoCapture(vid_fname)
                    cap.set(cv2.CAP_PROP_POS_MSEC, i*1000)
                    ret, frame = cap.read()
                    if ret:
                        if not os.path.exists('oob/train/{}'.format(phase)):
                            os.makedirs('oob/train/{}'.format(phase))
                        cv2.imwrite('oob/train/{}/{}_{}.jpg'.format(phase, vid_id, i), frame)
                else:
                    continue
                cap.release()
    elif i >= 500:
        vid_id = phases['vid_id'][i]
        vid_fname = phases['path'][i]
        phase = phases['phase'][i]
        if phase == 'oob':
            phase = 1
        elif phase != 'oob':
            phase = 0
        time_start = phases['time_start'][i]
        time_end = phases['time_end'][i]
        time_start_sec = convert_time(time_start)
        time_end_sec = convert_time(time_end)
        time_start_sec += 2
        time_end_sec -= 2
        print(vid_fname)
        for i in range(time_start_sec, time_end_sec):
            if i%10 == 0:
                cap = cv2.VideoCapture(vid_fname)
                cap.set(cv2.CAP_PROP_POS_MSEC, i*1000)
                ret, frame = cap.read()
                if ret:
                    if not os.path.exists('oob/test/{}'.format(phase)):
                        os.makedirs('oob/test/{}'.format(phase))
                    cv2.imwrite('oob/test/{}/{}_{}.jpg'.format(phase, vid_id, i), frame)
            else:
                continue
            cap.release()
# Out:
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_0.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_1.mp4
# unc/raw_ids/vid_3.mp4
# unc/raw_ids/vid_3.mp4
# unc/raw_ids/vid_3.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_4.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_5.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_7.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_22.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_13.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_14.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_15.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_16.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# unc/raw_ids/vid_23.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_0.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# yale/raw_ids/yale_3.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_6.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_11.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_24.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_12.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_17.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_21.mp4
# unc/raw_ids/vid_25.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# unc/raw_ids/vid_18.mp4
# yale/raw_ids/yale_18.mp4
# yale/raw_ids/yale_18.mp4
# yale/raw_ids/yale_18.mp4
# yale/raw_ids/yale_18.mp4
# yale/raw_ids/yale_18.mp4
# yale/raw_ids/yale_18.mp4
# yale/raw_ids/yale_18.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_4.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_5.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_7.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_8.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4
# yale/raw_ids/yale_9.mp4

# %%
#next we'll create a test set with unlabeled data
#we'll use the same method as above, but we'll just put the frames in a folder called 'test'
#we'll also create a csv file with the video id and the time of the frame

vid_id = 'vid_4'
vid_fname = str('raw_ids/' + vid_id + '.mp4')
time_start = '00H:00m:00s'
time_end = '01H:10m:06s'
time_start_sec = convert_time(time_start)
time_end_sec = convert_time(time_end)

# %%
save_dir = 'test'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
for i in range(time_start_sec, time_end_sec):
    if i%5 == 0:
        cap = cv2.VideoCapture(vid_fname)
        cap.set(cv2.CAP_PROP_POS_MSEC, i*1000)
        ret, frame = cap.read()
        if ret:
            cv2.imwrite('{}/{}_{}.jpg'.format(save_dir, vid_id, i), frame)

# %%
#next, let's create a timeline for the first video, colored by phase
phase_df = pd.DataFrame(columns=['fname', 'phase'])
for i in os.listdir('frames/train'):
    for file in os.listdir('frames/train/{}'.format(i)):
        if file.startswith('vid_4'):
            phase_df = phase_df.append({'fname': file, 'phase': i}, ignore_index=True)

for i in os.listdir('frames/test'):
    for file in os.listdir('frames/test/{}'.format(i)):
        if file.startswith('vid_4'):
            phase_df = phase_df.append({'fname': file, 'phase': i}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #next, let's create a timeline for the first video, colored by phase
# ----> 2 phase_df = pd.DataFrame(columns=['fname', 'phase'])
#       3 for i in os.listdir('frames/train'):
#       4     for file in os.listdir('frames/train/{}'.format(i)):
#
# NameError: name 'pd' is not defined

# %%
phase_df['fname'][0].split('_')[2].split('.')[0]
# Out:
# '205'

# %%
phase_df['time'] = phase_df['fname'].apply(lambda x: int(x.split('_')[2].split('.')[0]))
phase_df.head()
# Out:
#            fname     phase  time
# 0  vid_4_205.jpg  exposure   205
# 1  vid_4_150.jpg  exposure   150
# 2  vid_4_350.jpg  exposure   350
# 3  vid_4_345.jpg  exposure   345
# 4  vid_4_365.jpg  exposure   365

# %%
phase_df.sort_values(by='time', inplace=True)
phase_df.head()
# Out:
#            fname phase  time
# 69   vid_4_0.jpg   oob     0
# 67   vid_4_5.jpg   oob     5
# 64  vid_4_10.jpg   oob    10
# 66  vid_4_15.jpg   oob    15
# 72  vid_4_20.jpg   oob    20

# %%
#now we can plot the timeline using PolyCollection
from matplotlib.collections import PolyCollection
phases_str = [phase for phase in phase_df['phase'].unique()]

# %%
phases_cat = {phase: i for i, phase in enumerate(phases_str)}

# %%
colormapping = {phase: 'C' + str(i) for i, phase in enumerate(phases_str)}
colormapping
# Out:
# {'oob': 'C0',
#  'exposure': 'C1',
#  'hiatal_dissec': 'C2',
#  'fundus_mob': 'C3',
#  'eso_mob': 'C4',
#  'hiatal_repair': 'C5',
#  'wrap': 'C6',
#  'other': 'C7'}

# %%
phase_df.head()
# Out:
#            fname phase  time
# 69   vid_4_0.jpg   oob     0
# 67   vid_4_5.jpg   oob     5
# 64  vid_4_10.jpg   oob    10
# 66  vid_4_15.jpg   oob    15
# 72  vid_4_20.jpg   oob    20

# %%
#make a scatterplot of the points, colored by phase
fig, ax = plt.subplots(figsize=(20, 1))
#make the points big square markers
ax.scatter(phase_df['time'], [0]*len(phase_df), c=phase_df['phase'].apply(lambda x: colormapping[x]), marker='s', s=1000)
ax.set_yticks([])
ax.set_xlabel('Time (s)')
ax.set_title('Timeline of Video 4')
#add a legend
handles = [plt.plot([],[], marker="s", ms=10, ls="", mec=None, color=colormapping[phase], label=phase)[0]  for phase in phases_str]
plt.legend(handles=handles, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
test_preds = pd.read_csv('test/preds.csv', index_col=0)
test_preds.head()
# Out:
#         oob     other  phase_1_exposure  phase_2_hiatal_dissec  \
# 0  0.014538  0.886879          0.018921               0.023483
# 1  0.000020  0.003363          0.000002               0.000039
# 2  0.002529  0.724156          0.000920               0.004356
# 3  0.055615  0.735849          0.078103               0.053913
# 4  0.016452  0.783386          0.014081               0.029733
#
#    phase_3_fundus  phase_4_eso  phase_5_hiatal_repair  phase_6_wrap  \
# 0        0.011018     0.020968               0.010110      0.014082
# 1        0.000006     0.000007               0.003444      0.993120
# 2        0.001586     0.008698               0.093054      0.164701
# 3        0.011322     0.059134               0.003744      0.002321
# 4        0.019636     0.024814               0.023533      0.088364
#
#       image_fname
# 0  vid_1_3565.jpg
# 1  vid_1_4860.jpg
# 2   vid_1_865.jpg
# 3  vid_1_2300.jpg
# 4  vid_1_2465.jpg

# %%
test_preds.set_index('image_fname', inplace=True)

# %%
#create a new column 'pred' which is the phase with the highest probability
test_preds['pred'] = test_preds.apply(lambda x: x.idxmax(), axis=1)
test_preds.head()
# Out:
#                      oob     other  phase_1_exposure  phase_2_hiatal_dissec  \
# image_fname
# vid_1_3565.jpg  0.014538  0.886879          0.018921               0.023483
# vid_1_4860.jpg  0.000020  0.003363          0.000002               0.000039
# vid_1_865.jpg   0.002529  0.724156          0.000920               0.004356
# vid_1_2300.jpg  0.055615  0.735849          0.078103               0.053913
# vid_1_2465.jpg  0.016452  0.783386          0.014081               0.029733
#
#                 phase_3_fundus  phase_4_eso  phase_5_hiatal_repair  \
# image_fname
# vid_1_3565.jpg        0.011018     0.020968               0.010110
# vid_1_4860.jpg        0.000006     0.000007               0.003444
# vid_1_865.jpg         0.001586     0.008698               0.093054
# vid_1_2300.jpg        0.011322     0.059134               0.003744
# vid_1_2465.jpg        0.019636     0.024814               0.023533
#
#                 phase_6_wrap          pred
# image_fname
# vid_1_3565.jpg      0.014082         other
# vid_1_4860.jpg      0.993120  phase_6_wrap
# vid_1_865.jpg       0.164701         other
# vid_1_2300.jpg      0.002321         other
# vid_1_2465.jpg      0.088364         other

# %%
test_preds['pred'].value_counts()
# Out:
# other                    693
# phase_6_wrap             250
# phase_2_hiatal_dissec    179
# phase_1_exposure         109
# oob                       64
# phase_5_hiatal_repair     51
# phase_4_eso               14
# Name: pred, dtype: int64

# %%
fnames = [fname for fname in test_preds.index]
times = [int(fname.split('_')[2].split('.')[0]) for fname in fnames]
test_preds['time'] = times

# %%
test_df = test_preds[['time', 'pred']]
test_df.head()
# Out:
#                 time          pred
# image_fname
# vid_1_3565.jpg  3565         other
# vid_1_4860.jpg  4860  phase_6_wrap
# vid_1_865.jpg    865         other
# vid_1_2300.jpg  2300         other
# vid_1_2465.jpg  2465         other

# %%
#now we can plot the timeline using PolyCollection
fig, ax = plt.subplots(figsize=(20, 1))
#make the points big square markers
ax.scatter(test_df['time'], [0]*len(test_df), c=test_df['pred'].apply(lambda x: colormapping[x]), marker='s', s=1000)
ax.set_yticks([])
ax.set_xlabel('Time (s)')
ax.set_title('Timeline of Video 0')
#add a legend
handles = [plt.plot([],[], marker="s", ms=10, ls="", mec=None, color=colormapping[phase], label=phase)[0]  for phase in phases_str]
plt.legend(handles=handles, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
oob = test_df.loc[test_df['pred'] == 'other']
oob.head()
# Out:
#                 time   pred
# image_fname
# vid_1_3565.jpg  3565  other
# vid_1_865.jpg    865  other
# vid_1_2300.jpg  2300  other
# vid_1_2465.jpg  2465  other
# vid_1_270.jpg    270  other

# %%
#convert time to XXH:XXm:XXs format
def convert_time_back(time):
    hours = time//3600
    new_time = time - hours*3600
    minutes = new_time//60
    new_time = new_time - minutes*60
    seconds = new_time
    return '{}H:{}m:{}s'.format(hours, minutes, seconds)

# %%
oob['hhmmss'] = oob['time'].apply(lambda x: convert_time_back(x))
# Out:
# /tmp/ipykernel_706724/2466309794.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oob['hhmmss'] = oob['time'].apply(lambda x: convert_time_back(x))

# %%
oob.head(50)
# Out:
#                 time   pred      hhmmss
# image_fname
# vid_1_3565.jpg  3565  other  0H:59m:25s
# vid_1_865.jpg    865  other  0H:14m:25s
# vid_1_2300.jpg  2300  other  0H:38m:20s
# vid_1_2465.jpg  2465  other   0H:41m:5s
# vid_1_270.jpg    270  other   0H:4m:30s
# vid_1_720.jpg    720  other   0H:12m:0s
# vid_1_985.jpg    985  other  0H:16m:25s
# vid_1_6020.jpg  6020  other  1H:40m:20s
# vid_1_5765.jpg  5765  other   1H:36m:5s
# vid_1_5485.jpg  5485  other  1H:31m:25s
# vid_1_2395.jpg  2395  other  0H:39m:55s
# vid_1_220.jpg    220  other   0H:3m:40s
# vid_1_2345.jpg  2345  other   0H:39m:5s
# vid_1_5275.jpg  5275  other  1H:27m:55s
# vid_1_2295.jpg  2295  other  0H:38m:15s
# vid_1_1630.jpg  1630  other  0H:27m:10s
# vid_1_365.jpg    365  other    0H:6m:5s
# vid_1_4215.jpg  4215  other  1H:10m:15s
# vid_1_730.jpg    730  other  0H:12m:10s
# vid_1_4485.jpg  4485  other  1H:14m:45s
# vid_1_3850.jpg  3850  other   1H:4m:10s
# vid_1_2015.jpg  2015  other  0H:33m:35s
# vid_1_3325.jpg  3325  other  0H:55m:25s
# vid_1_3135.jpg  3135  other  0H:52m:15s
# vid_1_1110.jpg  1110  other  0H:18m:30s
# vid_1_6230.jpg  6230  other  1H:43m:50s
# vid_1_2960.jpg  2960  other  0H:49m:20s
# vid_1_3845.jpg  3845  other    1H:4m:5s
# vid_1_780.jpg    780  other   0H:13m:0s
# vid_1_3655.jpg  3655  other   1H:0m:55s
# vid_1_5900.jpg  5900  other  1H:38m:20s
# vid_1_4735.jpg  4735  other  1H:18m:55s
# vid_1_4805.jpg  4805  other   1H:20m:5s
# vid_1_4990.jpg  4990  other  1H:23m:10s
# vid_1_6660.jpg  6660  other   1H:51m:0s
# vid_1_3255.jpg  3255  other  0H:54m:15s
# vid_1_3930.jpg  3930  other   1H:5m:30s
# vid_1_980.jpg    980  other  0H:16m:20s
# vid_1_6440.jpg  6440  other  1H:47m:20s
# vid_1_3520.jpg  3520  other  0H:58m:40s
# vid_1_320.jpg    320  other   0H:5m:20s
# vid_1_3895.jpg  3895  other   1H:4m:55s
# vid_1_4560.jpg  4560  other   1H:16m:0s
# vid_1_5115.jpg  5115  other  1H:25m:15s
# vid_1_4600.jpg  4600  other  1H:16m:40s
# vid_1_95.jpg      95  other   0H:1m:35s
# vid_1_3575.jpg  3575  other  0H:59m:35s
# vid_1_485.jpg    485  other    0H:8m:5s
# vid_1_1035.jpg  1035  other  0H:17m:15s
# vid_1_240.jpg    240  other    0H:4m:0s
